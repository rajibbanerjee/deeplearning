# %% [markdown]
# <a href="https://colab.research.google.com/github/rajibbanerjee/deeplearning/blob/master/ML_Bruteforce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set()

# Data preperation
x = np.linspace(0, 5, 100)
y = list(map(lambda x: 2.537 * np.power(x,1.289), list(x)))
y_0 = y1 + 0.5*np.random.normal(size=100)

# Guess
y_initial = list(map(lambda x: 1.00 * np.power(x,1.05), list(x)))
y2 = list(map(lambda x: 1.39 * np.power(x,1.01), list(x)))
y3 = list(map(lambda x: 1.75 * np.power(x,1.12), list(x)))
y4 = list(map(lambda x: 1.92 * np.power(x,1.18), list(x)))
y5 = list(map(lambda x: 2.24 * np.power(x,1.23), list(x)))
y6 = list(map(lambda x: 2.45 * np.power(x,1.25), list(x)))

y1 = np.asarray(y)

# Plot
c = np.random.randint(0, 50, 50)
plt.scatter(x, y_0, c)
plt.plot(x, y1, 'g--', x, y2, 'r--', x, y3, 'b--', x, y4, 'y--', x, y5, 'c--', x, y6, 'm--', x, y_initial, 'b--', x, y, 'g--')
plt.plot(x, y_initial, 'g--')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
